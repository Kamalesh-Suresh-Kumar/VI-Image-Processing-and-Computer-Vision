# %%
! pip install opencv-python numpy matplotlib
# Out:
# Requirement already satisfied: opencv-python in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (4.13.0.92)
# Requirement already satisfied: numpy in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (2.4.3)
# Requirement already satisfied: matplotlib in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "lamborghini.jpeg"
img = cv.imread(path)

if img is None:
    print("Image not found")
else:
    print("Image loaded successfully")
# Out:
# Image loaded successfully

# %%
# Convert BGR to RGB
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.title("Original Image")
plt.axis("off")
plt.show()

# %%
# Getting image size and source points
h, w = img.shape[:2]
src_pts = np.float32([
    [0, 0],        # top-left
    [w, 0],        # top-right
    [w, h],        # bottom-right
    [0, h]         # bottom-left
])

# %%
# Define destination points
dst_pts = np.float32([
    [100, 100],          # shifted top-left
    [w-200, 0],         # compressed top-right
    [w, h],            # stretched bottom-right
    [0, h-200]          # shifted bottom-left
])

# %%
# Compute Homography Matrix
H = cv.getPerspectiveTransform(src_pts, dst_pts)
print("Homography Matrix:\n", H)
# Out:
# Homography Matrix:
#  [[ 3.69704992e-01 -1.40646976e-01  1.00000000e+02]
#  [-1.25000000e-01  3.69704992e-01  1.00000000e+02]
#  [-4.25491679e-04 -4.07737924e-04  1.00000000e+00]]

# %%
# Apply Warping
warped = cv.warpPerspective(img, H, (w, h))
warped_rgb = cv.cvtColor(warped, cv.COLOR_BGR2RGB)

plt.imshow(warped_rgb)
plt.title("Linear Warped Image")
plt.axis("off")
plt.show()

# %%
# Save this image
cv.imwrite("warped_lamborghini_1.png", warped)
print("Warped image saved")
# Out:
# Warped image saved

# %%
# Getting image size
rows, cols = img.shape[:2]

center_x = cols // 2
center_y = rows // 2

# Creating warping map
map_x = np.zeros((rows, cols), np.float32)
map_y = np.zeros((rows, cols), np.float32)

k = 0.00001  # distortion strength

for i in range(rows):
    for j in range(cols):

        dx = j - center_x
        dy = i - center_y

        r2 = dx*dx + dy*dy   # distance squared

        map_x[i, j] = j + k * dx * r2
        map_y[i, j] = i + k * dy * r2

# %%
# Display maps
print(map_x)
print()
print(map_y)
# Out:
# [[-1144.1    -1137.0518 -1130.0275 ...  1923.027   1930.0275  1937.0518]
#  [-1141.264  -1134.2228 -1127.2056 ...  1920.2123  1927.2056  1934.2228]
#  [-1138.436  -1131.4019 -1124.3917 ...  1917.4055  1924.3917  1931.4019]
#  ...
#  [-1138.436  -1131.4019 -1124.3917 ...  1917.4055  1924.3917  1931.4019]
#  [-1141.264  -1134.2228 -1127.2056 ...  1920.2123  1927.2056  1934.2228]
#  [-1144.1    -1137.0518 -1130.0275 ...  1923.027   1930.0275  1937.0518]]
#
# [[-1015.38873 -1012.5523  -1009.72296 ... -1006.9007  -1009.72296
#   -1012.5523 ]
#  [-1009.0186  -1006.1902  -1003.3688  ... -1000.5545  -1003.3688
#   -1006.1902 ]
#  [-1002.6698   -999.8493   -997.0359  ...  -994.22955  -997.0359
#    -999.8493 ]
#  ...
#  [ 1712.6698   1709.8492   1707.0359  ...  1704.2295   1707.0359
#    1709.8492 ]
#  [ 1719.0187   1716.1902   1713.3688  ...  1710.5544   1713.3688
#    1716.1902 ]
#  [ 1725.3888   1722.5522   1719.7229  ...  1716.9008   1719.7229
#    1722.5522 ]]

# %%
# Apply warping
warped = cv.remap(img, map_x, map_y, cv.INTER_LINEAR)

# Display warped image
warped_rgb = cv.cvtColor(warped, cv.COLOR_BGR2RGB)

plt.imshow(warped_rgb)
plt.title("Non-linear Warped Image")
plt.axis("off")
plt.show()

# %%
# Save this image
cv.imwrite("warped_lamborghini_2.png", warped)
print("Warped image saved")
# Out:
# Warped image saved
