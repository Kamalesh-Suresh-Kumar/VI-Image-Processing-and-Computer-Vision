# %%
! pip install numpy opencv-python matplotlib
# Out:
# Requirement already satisfied: numpy in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (2.4.3)
# Requirement already satisfied: opencv-python in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (4.13.0.92)
# Requirement already satisfied: matplotlib in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\kamal\onedrive\desktop\image processing and computer vision\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
def equalize_hist(image, L=256):
    # Step 1: Find unique intensity values and their counts
    intensity_levels, counts = np.unique(image, return_counts=True)
    total_pixels = image.size

    # Step 2: Calculate PDF and CDF
    pdf = counts / total_pixels
    cdf = np.cumsum(pdf)

    # Step 3: Create transformation function
    transform = np.floor((L - 1) * cdf).astype(np.uint8)

    # Step 4: Create a mapping dictionary and apply the mapping
    mapping = dict(zip(intensity_levels, transform))
    equalized_image = np.vectorize(mapping.get)(image)

    return equalized_image.astype(np.uint8)

# %%
# Read image in grayscale
path = "roses.jpeg"
image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)

# Custom histogram equalization
custom_image = equalize_hist(image)

# OpenCV histogram equalization
opencv_image = cv2.equalizeHist(image)

# %%
# Display images
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.imshow(image, cmap='gray')
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,3,2)
plt.imshow(custom_image, cmap='gray')
plt.title("Custom Equalized Image")
plt.axis("off")

plt.subplot(1,3,3)
plt.imshow(opencv_image, cmap='gray')
plt.title("OpenCV Equalized Image")
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
# Display Histograms
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.hist(image.ravel(), bins=256, range=[0,256])
plt.title("Original Histogram")

plt.subplot(1,3,2)
plt.hist(custom_image.ravel(), bins=256, range=[0,256])
plt.title("Custom Equalized Histogram")

plt.subplot(1,3,3)
plt.hist(opencv_image.ravel(), bins=256, range=[0,256])
plt.title("OpenCV Equalized Histogram")

plt.tight_layout()
plt.show()
